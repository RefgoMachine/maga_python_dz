# %% [markdown]
# # Задание 1
#
# Печатные газеты использовали свой формат дат для каждого выпуска.
# Для каждой газеты из списка напишите формат указанной даты для перевода в объект datetime:
#
# ```
# The Moscow Times - Wednesday, October 2, 2002
#
# The Guardian - Friday, 11.10.13
#
# Daily News - Thursday, 18 August 1977
# ```
#
# #### Пример работы программы
#
# ```
# Программа должна выводить на экран объекты типа datetime, соответствующие датам в условии задачи
# ```

# %%
from datetime import datetime

dt_list = [{"name": "The Moscow Times", "dt": datetime(2002, 10, 2).strftime("%A, %B %-d, %Y")},
           {"name": "The Guardian", "dt": datetime(2013, 10, 11).strftime("%A, %-d.%m.%y")},
           {"name": "Daily News", "dt": datetime(1977, 8, 18).strftime("%A, %-d %B %Y")}]

for dt in dt_list:
    print(f"{dt["name"]} - {dt["dt"]}")
# Out:
# The Moscow Times - Wednesday, October 2, 2002
# The Guardian - Friday, 11.10.13
# Daily News - Thursday, 18 August 1977

# %% [markdown]
# # Задание 2
# Напишите функцию date_range, которая возвращает список дат за период от start_date до end_date.
# Даты должны вводиться в формате YYYY-MM-DD.
# В случае неверного формата или при start_date > end_date должен возвращаться пустой список.
#
#
#
# #### Примеры работы программы:
#
# ```
# date_range(‘2022-01-01’, ‘2022-01-03’)
#
# [‘2022-01-01’, ‘2022-01-02’, ‘2022-01-03’]
# ```

# %%
import re
from datetime import datetime, timedelta

def date_range(start_date: str, end_date: str) -> list:
    #Можно перехватить через try catch, но не мой стиль
    regexp = re.compile(r"[0-9]{4}-[0-9]{1,2}-[0-9]{1,2}")
    if not re.match(regexp, start_date) and not re.match(regexp, end_date):
        return []

    start_date = datetime.strptime(start_date, "%Y-%m-%d")
    end_date = datetime.strptime(end_date, "%Y-%m-%d")

    if start_date > end_date:
        return []

    current_date = start_date
    list_of_dates = []
    
    while current_date <= end_date:
        list_of_dates.append(current_date.strftime("%Y-%m-%d"))
        current_date += timedelta(days=1)

    return list_of_dates

#Правильный сценарий
print(date_range('2022-06-27', '2022-06-30'))

#Неправильные
print(date_range('2022-06-30', '2022-06-27'))
print(date_range('27-06-2022', '30-06-2022'))
# Out:
# ['2022-06-27', '2022-06-28', '2022-06-29', '2022-06-30']
# []
# []
